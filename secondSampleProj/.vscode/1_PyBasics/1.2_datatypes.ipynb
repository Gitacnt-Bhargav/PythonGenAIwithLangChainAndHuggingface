# %%
results = "Hello" + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 results = "Hello" + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
results = "Hello" + str(5)
print(results)
# Out:
# Hello5
