# %%
age = 16

if age>=18:
    print("You are eligible to vote")
else:
    print("You are minor")
# Out:
# You are minor

# %%
age = 15

if age < 13:
    print("Hey, you are a child") 
elif age <18:
    print("You are a teenager")
else:
    print("You are an adult")
# Out:
# You are a teenager

# %%
#Nested condition statement

num = int(input("Enter the number: "))

if num>0:
    print("The number is positive")
    print(num%2)
    if not num%2: # here num%2 is 0 when given 10 as input, in python, 0 is considered as false, so not is used to make it become true. Any non zero number is considered as True.
        print("Then number is even")
    else:
        print("The number is odd")

else:
    print("Number is 0 or negative")
# Out:
# Number is 0 or negative

# %%
## Determine if an year is a leap year

year = int(input("Enter year"))

if year>0:
    print("Checking year")
    if year%4==0:
        if year%100==0:
            if year%400==0:
                print(year, "Year is leap year")
            else:
                print(year, "Year is not leap year")
        else:
            # If divisible by 4 but NOT by 100, it IS a leap year
            print(year, "Year is leap year")
    else:
        print(year, "Year is not leap year")
else:
    print("Invalid year given")


# Can also be written as
# if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
#     print(year, "is a leap year")
# else:
#     print(year, "is not a leap year")
# Out:
# Checking year
# 100 Year is not leap year

# %%
# Simple calculator program

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operator = input("Enter operator from (+,-,*,/): ")

if operator=='+':
    result = num1+num2
elif operator=='-':
    result = num1-num2
elif operator=='*':
    result = num1*num2
elif operator=='/':
    if num2!=0:
        result = num1/num2
    else:
        print("Error, Division by zero")
else:
    print("Enter valid operator")

print("Result: ", result)
# Out:
# Result:  80.0
