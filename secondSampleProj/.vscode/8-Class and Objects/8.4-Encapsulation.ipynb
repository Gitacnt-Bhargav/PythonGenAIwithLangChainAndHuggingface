# %% [markdown]
# ### Encapsulation And Abstraction
#
# Encapsulation and abstaction are two fundamental principles of OOP.
# Encapsulation involves bundling data and methods that operate on the data within a single unit, while
# Abstraction involves hiding complex implementation details and exposing only the necessary features
#
# #### Encapsulation
#
# Encapsulation is the concept of wrapping data (variables) and methods (functions) together as a single unit.
# It restricts direct access to some of the object's components, which is a means of preventing accidental
# interfence and misuse of the data

# %%
## Encapsulation with Getter and Setter methods

### Public, protected and private variables or access modifiers

class Person:
    def __init__(self, name, age):
        self.name = name # public variable
        self.age = age # public variable

person = Person("Krish",34)

print(person.name)

dir(person) # will have age and name listed


def get_name(person):
    return person.name

get_name(person)
# Out:
# Krish
# 'Krish'

# %%
class Person:
    def __init__(self, name, age, gender):
        self.__name = name # private variable - not accessible outside class
        self.__age = age # private variable
        self.gender = gender

person = Person("Krish",34,"Male")


dir(person) # will have gender only listed and not name and age due to access modifier instead can see __Person__age and __Person__name
# print(person.name)
# Out:
# ['_Person__age',
#  '_Person__name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'gender']

# %%
def get_name(person):
    return person.__name

person1 = Person("Krish",34,"Male")
get_name(person1) ## wont be able to access this - AttributeError: 'Person' object has no attribute '__name'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 5
#       2     return person.__name
#       4 person1 = Person("Krish",34,"Male")
# ----> 5 get_name(person1) ## wont be able to access this - AttributeError: 'Person' object has no attribute '__name'
#
# Cell In[15], line 2, in get_name(person)
#       1 def get_name(person):
# ----> 2     return person.__name
#
# AttributeError: 'Person' object has no attribute '__name'

# %%
## Protected variable

class Person:
    def __init__(self, name, age, gender):
        self._name = name # protected variable - accessible only from derived class
        self._age = age # protected variable
        self.gender = gender

class Employee(Person):
    def __init__(self, name, age, gender):
        super().__init__(name, age, gender)

employee = Employee("Krish",34,"Male")
print(employee._name)
# Out:
# Krish

# %%
# Encapsulation with getter and setter

class Person:
    def __init__(self, name,age):
        self.__name = name # Private access modified
        self.__age = age # Private access modified

    ## getter for name
    def get_name(self):
        return self.__name

    ## Setter for name
    def set_name(self,name):
        self.__name = name

    ## getter for age
    def get_age(self):
        return self.__age

    ## Setter for age
    def set_age(self,age):
        if(age>0):
            self.__age = age
        else:
            print("Age cannot be negative")

person = Person("Krish",34)

## Access and modify private variable using getter and setter

print(person.get_name())
print(person.get_age())

person.set_age(35)
print(person.get_age())

person.set_age(-10)
# Out:
# Krish
# 34
# 35
# Age cannot be negative
