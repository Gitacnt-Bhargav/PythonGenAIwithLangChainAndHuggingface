# %% [markdown]
# ### Polymorphism

# %%
# It provides a way to perform a single action in different forms.

# %%
# Method overriding

# Method overriding allows a child class to provide a specific implimentation of a method that is 
# already defined in its parent class

# %%
## Base class

class Animal:
    def speak(self):
        return "Sound of the animal"
    
# Derived class
class Dog(Animal):
    def speak(self):
        return "Sound of dog is Woof!"
    
# Derived class
class Cat(Animal):
    def speak(self):
        return "Sound of cat is meow!"
    
## Function that demonstrates polymorphism

def animal_speak(animal):
    print(animal.speak())

dog = Dog()
cat = Cat()
animal = Animal()
print(dog.speak())
print(cat.speak())

animal_speak(dog)
animal_speak(animal)
animal_speak(cat)
# Out:
# Sound of dog is Woof!
# Sound of cat is meow!
# Sound of dog is Woof!
# Sound of the animal
# Sound of cat is meow!

# %%
## Polymorphism with functions and methods

## Base class
import math

class Shape:
    def area(self):
        return "The area of the figure"
    
class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height
    def area(self):
        return self.width * self.height

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        return (self.radius)**2 * math.pi 
    
## function that demonstrates polymorphisn

def print_area(shape):
    print(f"the are is {shape.area()}")

rectangle = Rectangle(4,5)
circle = Circle(3)

print_area(rectangle)
print_area(circle)
# Out:
# the are is 20
# the are is 28.274333882308138

# %%
## Polymorphism with Abstract base class (interface in other language)

### Abstract base classes (ABCs) are used to define common methods for a group of related objects
### They can enforce the derived class implement particular methods, promoting consistency across 
### different implementations

from abc import ABC, abstractmethod

## define an abstract class

class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass

## derived class 1
class Car(Vehicle):
    def start_engine(self):
        return "Car engine started"
    
## derived class 2
class MotorCycle(Vehicle):
    def start_engine(self):
        return "Motor cycle engine started"
    
## created objects of Car and MotorCycle

motorCycle = MotorCycle()
motorCycle.start_engine()
# Out:
# 'Motor cycle engine started'
