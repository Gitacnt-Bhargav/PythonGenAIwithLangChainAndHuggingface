# %% [markdown]
# ### Word2Vec using CBOW
#
# Prereq - ANN, LOSS function, Optimizers
#
# In Word2Vec we have pretrained models like done by Google on 3Bn words and Pre trained models also which is a model from scratch

# %% [markdown]
# ### CBOW - Type of Word2Vec
#
# -- How model is created ?
#
# Now to solve any problem we will have a datasets. Trained models of Word2Vec by Google by Deeplearning are trained on huge data set
#
# Corpus:
#
# [ iNeuron Company is related to Data science. ]
#
# Firstly, We will select a window size
# Window size is very important to create input and output data so that we can train our model. eg. window size initially is 5 - which means i am selecting 5 words and from those 5 words center word is selected.
#
# i/p                                                                                                                 o/p
# iNeuron, Company, Related, to [forward and backword words of that center word of first 5 words]                     IS
#
# Next 5 words where center word is related
# i/p                                                                                                                 o/p
# Company, Is, To, Data                                                                                               Related
#
# i/p                                                                                                                 o/p
# Is, related, Data, Science                                                                                          To
#
#
# Now, we have to train model with this
# For that, we need to convert the words in Vocabulary to vector using OHE for eg.
# iNeuron 1000000
# Company 0100000
# Related 0001000
# To 00000100
#
#
# Next Step is:
#
# CBOW - what is CBOW ?
# This is fully connected neural network.
