# %% [markdown]
# ### Stream lit
#
# is open source app framework for ML and DS projects. It allows you to create beutiful web applications for your machine learning and data science projects with simple Py scripts
