# %% [markdown]
# ## Real-World examples of Lists

# %%
# Create a to do list to keep track of tasks

to_do_list= ["Buy groceries","Clean the house","Pay bills"]

## adding to task

to_do_list.append("Schedule meeting")
to_do_list.append("Go for a Run")

#Removing a completed task
to_do_list.remove("Clean the house")

## checking if a task in in the list

if "Pay bills" in to_do_list:
    print("Dont forget to pay the utility bills")

print("To do list remaining:") 
for task in to_do_list:
    print(f"-{task} ")
# Out:
# Dont forget to pay the utility bills
# To do list remaining:
# -Buy groceries
# -Pay bills
# -Schedule meeting
# -Go for a Run

# %%
## Organizing Student Grades:

grades = [85, 92, 78, 90, 88]

## Adding a new Grade
grades.append(95)

#calculating the average grade
average_grade = sum(grades) / len(grades)
print(f"Average grade: {average_grade}")

#Finding the highest and lowest grade
highest_grade = max(grades)
lowest_grade = min(grades)

print(f"lowest grade is: {lowest_grade} and highest grade is: {highest_grade}")
# Out:
# Average grade: 88.0
# lowest grade is: 78 and highest grade is: 95

# %%
# Managing an inventory

inventory = ["apples","bananas","oranges","grapes"]

#Adding a new item
inventory.append("strawberry")

#Removing an item that is our of stock
inventory.remove("bananas")

#Checking if an item is in stock
item = "oranges"
if item in inventory:
    print(f"{item} in stock")
else:
    print(f"{item} is out of stock")
    
# Printing the inventory

print("Inventory list")

for item in inventory:
    print(f"- {item}")
# Out:
# oranges in stock
# Inventory list
# - apples
# - oranges
# - grapes
# - strawberry

# %%
## Collecting user feedback

# Use a list to collect and analyze a feedback

feedback = ["Great service!","Very satisfied","Could be better","Excellent experience"]

#Adding new feedback
feedback.append("Not happy with the service")

#Counting specific feedback
positive_feedback_count = sum( 1 for comment in feedback if "great" in comment.lower() or "excellent" in comment.lower())
print(f"Positive feedback count: {positive_feedback_count} out of {len(feedback)} feedbacks")

print("User feedback:")
for comment in feedback:
    print(f"- {comment}")
# Out:
# Positive feedback count: 2 out of 5 feedbacks
# User feedback:
# - Great service!
# - Very satisfied
# - Could be better
# - Excellent experience
# - Not happy with the service
